# %%
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt
import calendar
from matplotlib.pyplot import figure
import pymongo
from pymongo import MongoClient
import numpy as np
import math
from datetime import datetime
import statistics
from math import sqrt
from numpy import log as ln
from sklearn.neighbors import KNeighborsRegressor as knr
from sklearn.metrics import confusion_matrix, accuracy_score, r2_score
from sklearn.metrics import roc_auc_score
import time
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression as lr
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('products.csv')

# %%
df['Popularity'] = 0

# %%
df
# Out:
#                           Category Sub-Category            Sub-Sub-Category  \
# 0     Watches Sunglasses Jewellery      Watches                       Women
# 1                  Bags and Travel   Women Bags  Cross Body & Shoulder Bags
# 2                   Bedding & Bath         Bath                   Bath Mats
# 3                   Bedding & Bath         Bath                 Bath Towels
# 4                   Bedding & Bath         Bath             Bathroom Scales
# ...                            ...          ...                         ...
# 9708  Watches Sunglasses Jewellery      Eyewear                  Sunglasses
# 9709  Watches Sunglasses Jewellery    Jewellery                         Men
# 9710  Watches Sunglasses Jewellery    Jewellery                       Women
# 9711  Watches Sunglasses Jewellery      Watches                        Kids
# 9712  Watches Sunglasses Jewellery      Watches                         Men
#
#       Year  Month  Day                 Date     Label  Week_Day  Popularity
# 0     2023      1    6  2023-01-06 00:00:00  0.023574    Friday           0
# 1     2022     11   26  2022-11-26 00:00:00  0.036782  Saturday           0
# 2     2022     11   26  2022-11-26 00:00:00  0.029219  Saturday           0
# 3     2022     11   26  2022-11-26 00:00:00  0.035893  Saturday           0
# 4     2022     11   26  2022-11-26 00:00:00  0.032787  Saturday           0
# ...    ...    ...  ...                  ...       ...       ...         ...
# 9708  2023      1    6  2023-01-06 00:00:00  0.023057    Friday           0
# 9709  2023      1    6  2023-01-06 00:00:00  0.023069    Friday           0
# 9710  2023      1    6  2023-01-06 00:00:00  0.024267    Friday           0
# 9711  2023      1    6  2023-01-06 00:00:00  0.024054    Friday           0
# 9712  2023      1    6  2023-01-06 00:00:00  0.024100    Friday           0
#
# [9713 rows x 10 columns]

# %%
x_train = []
x_test = []
y_train = []
y_test = []

# %%
df['New Cat'] = df['Category'] + '/' + df['Sub-Category'] + '/' + df['Sub-Sub-Category']

# %%
x_train_df = pd.DataFrame(columns=['Category',	'Sub-Category',	'Sub-Sub-Category',	'Year',	'Month',	'Day',	'Week_Day'])
x_test_df = pd.DataFrame(columns=['Category',	'Sub-Category',	'Sub-Sub-Category',	'Year',	'Month',	'Day',	'Week_Day'])
y_train_df = pd.DataFrame(columns=['Label'])
y_test_df = pd.DataFrame(columns=['Label'])

# %%
#X_train(all columns except New Cat, Date, Label)
#Y_train(Label)
for i in df['New Cat'].unique():
    temp2 = df[df['New Cat'] == i]
    x_train.append(temp2.drop(['New Cat', 'Date', 'Label'], axis=1)[0:int(len(temp2) * 0.8)])

    x_test.append(temp2.drop(['New Cat', 'Date', 'Label'], axis=1)[int(len(temp2) * 0.8):])
    y_train.append(temp2['Label'][0:int(len(temp2) * 0.8)].to_frame(name="Label"))

    y_test.append(temp2['Label'][int(len(temp2) * 0.8):].to_frame(name="Label"))

# %%
for i in x_train:
    x_train_df = x_train_df.append(i)

for i in x_test:
    x_test_df = x_test_df.append(i)

for i in y_train:
    y_train_df = y_train_df.append(i)

for i in y_test:
    y_test_df = y_test_df.append(i)

# %%
le = preprocessing.LabelEncoder()
x_train_df["Category"] = le.fit_transform(x_train_df["Category"])
x_train_df["Sub-Category"] = le.fit_transform(x_train_df["Sub-Category"])
x_train_df["Sub-Sub-Category"] = le.fit_transform(x_train_df["Sub-Sub-Category"])
#df["Day"] = le.fit_transform(df["Day"])
x_train_df["Week_Day"] = le.fit_transform(x_train_df["Week_Day"])

x_test_df["Category"] = le.fit_transform(x_test_df["Category"])
x_test_df["Sub-Category"] = le.fit_transform(x_test_df["Sub-Category"])
x_test_df["Sub-Sub-Category"] = le.fit_transform(x_test_df["Sub-Sub-Category"])
#df["Day"] = le.fit_transform(df["Day"])
x_test_df["Week_Day"] = le.fit_transform(x_test_df["Week_Day"])

x_test_df = x_test_df.sort_index()
x_train_df = x_train_df.sort_index()

# %%
regressor = DecisionTreeRegressor
#xtrain, xtest, ytrain, ytest = train_test_split(x, y, train_size = 0.80, random_state = 0)

# %%
model = regressor()
model.fit(x_train_df, y_train_df)
# Out:
# DecisionTreeRegressor()

# %%
yhat = model.predict(x_test_df)

# %% [markdown]
# # Plotting only the first 100 values for simplicity of graph

# %%
yhat = yhat[:50]
y_test_df = y_test_df[:50]

# %%
x = []
for i in range(len(y_test_df)):
    x.append(i)

# %%
y_test_df
# Out:
#          Label
# 7459  0.029847
# 8051  0.028071
# 8649  0.024206
# 7471  0.027342
# 8063  0.027863
# 8661  0.025545
# 9156  0.024470
# 7476  0.028907
# 8068  0.024755
# 9161  0.023674
# 7477  0.024228
# 8069  0.027668
# 9162  0.021861
# 7479  0.027932
# 8071  0.025618
# 9164  0.023530
# 7480  0.020732
# 8072  0.022237
# 9165  0.027922
# 7481  0.026585
# 8073  0.024863
# 9166  0.022002
# 7482  0.030514
# 8074  0.021167
# 9167  0.018977
# 7483  0.023706
# 8075  0.030621
# 9168  0.029505
# 7484  0.026042
# 8076  0.026653
# 9169  0.023600
# 7485  0.029255
# 8077  0.027677
# 9170  0.022139
# 7486  0.029653
# 8078  0.026778
# 9171  0.023938
# 7487  0.027916
# 8079  0.027228
# 9172  0.026200
# 7489  0.030943
# 8081  0.024241
# 9174  0.024481
# 7490  0.029999
# 8082  0.026081
# 8666  0.025232
# 9175  0.024274
# 7491  0.028386
# 8083  0.026200
# 8667  0.024841

# %%
plt.plot(x, yhat)
plt.plot(x, y_test_df)
plt.show()
